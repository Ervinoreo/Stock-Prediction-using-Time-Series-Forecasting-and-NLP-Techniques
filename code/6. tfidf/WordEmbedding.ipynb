# %%
import pandas as pd
import re
import nltk

from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize

from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/cs3244_notebook/
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/cs3244_notebook/'
# /content/drive/MyDrive/cs3244_notebook

# %%
data = pd.read_csv(r"tesla_final.csv")
df = pd.DataFrame(data)

# %%
print(df.head(3))
# Out:
#         Dates  Closed Price  \
# 0  2010-06-29      1.592667
# 1  2010-06-30      1.588667
# 2  2010-07-01      1.464000
#
#                                        Combined_Desc  Percentage_Change
# 0  2013 Tesla Roadster to be completely built in-...                NaN
# 1  Tesla Roadster reaches China’s Great Wall Tesl...          -0.251148
# 2  Tesla Roadster gets version 2.5 upgrade Tesla ...          -7.847274

# %%
# Text preprocessing
# !pip install gensim nltk
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))
# Remove Punctuation
df['Combined_Desc'] = df['Combined_Desc'].apply(lambda x: re.sub(r'[^\w\s]', '', x))

# Remove stopwords & Lowercasing
def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    filtered_text = [word.lower() for word in word_tokens if word.lower() not in stop_words]
    return ' '.join(filtered_text)

df['Combined_Desc'] = df['Combined_Desc'].apply(remove_stopwords)
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.25.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Lemmatization
lmtzr = WordNetLemmatizer()

def lemmatize_text(text):
    tokens = word_tokenize(text)
    lemmatized_tokens = [lmtzr.lemmatize(word) for word in tokens]
    return ' '.join(lemmatized_tokens)

df['lemmatized_text'] = df['Combined_Desc'].apply(lemmatize_text)
df['lemmatized_text'][0]
# Out:
# '2013 tesla roadster completely built inhouse tesla ups price volume initial public offering tesla motor share jump market debut tesla ipo share pop drop rally market value 17 billion tesla motor ipo win road ahead bumpy tesla post secondbiggest rally 2010 u ipo tesla ipo raise 2261m stock surge 41 percent tesla ipo afterhours trading big winner mean green tsla tesla ipo investor giddy auto expert wary jun 29 2010 voros tesla prof wall street still belief fairy tale tesla raise 226 million ipo tesla open showroom copenhagen get ready first ipo 2010 tesla ipo electriccar maker stock 41 percent debut weve poring tesla ipo filing sec hidden within indecipherable legalese little gem u interested tesla motor inc nasdaqtsla manufacturer electric vehicle electric powertrain component today announced initial public offering investor snapped tesla share even broader market took beating stock soared 689 405 percent offering price close dow 250 point today best day ipo tesla share rallying initial scare tesla motor rang tesla motor ipo sold quickly share company rose 41 percent first day trading tesla ability navigate tesla motor inc electriccar company hasnt posted profit rallied 41 percent raising 226 million first initial public offering tesla motor raised 2261 million dollar initial public offering tuesday share surged 41 percent investor snapped stock appeal established love car inspire people look brighter future image dutiful marketing mostly responsible welcome tsla tesla motor raise 266 million ipo new york cnnmoneycom investor snapped share tesla motor public debut tuesday fundamental lack catch tesla quickly point stock fall favor quicker delorean amish convention tesla raise 226 million ipo tesla become first american car company go public 54 year raised 226 million tesla open showroom copenhagen get ready first ipo 2010 tesla ipo electriccar maker stock 41 percent debut'

# %%
print(df.head(3))
# Out:
#         Dates  Closed Price  \
# 0  2010-06-29      1.592667
# 1  2010-06-30      1.588667
# 2  2010-07-01      1.464000
#
#                                        Combined_Desc  Percentage_Change  \
# 0  2013 tesla roadster completely built inhouse t...                NaN
# 1  tesla roadster reaches chinas great wall tesla...          -0.251148
# 2  tesla roadster gets version 25 upgrade tesla r...          -7.847274
#
#                                      lemmatized_text
# 0  2013 tesla roadster completely built inhouse t...
# 1  tesla roadster reach china great wall tesla op...
# 2  tesla roadster get version 25 upgrade tesla re...

# %%
# TF-IDF
tfidf = TfidfVectorizer(max_features=100)
tfidf_matrix = tfidf.fit_transform(df['lemmatized_text'])
df['embeddings'] = list(tfidf_matrix.toarray())
print(df.head(3))
# result_df.to_csv('Word_Embedding.csv', index=False)
# Out:
#         Dates  Closed Price  \
# 0  2010-06-29      1.592667
# 1  2010-06-30      1.588667
# 2  2010-07-01      1.464000
#
#                                        Combined_Desc  Percentage_Change  \
# 0  2013 tesla roadster completely built inhouse t...                NaN
# 1  tesla roadster reaches chinas great wall tesla...          -0.251148
# 2  tesla roadster gets version 25 upgrade tesla r...          -7.847274
#
#                                      lemmatized_text  \
# 0  2013 tesla roadster completely built inhouse t...
# 1  tesla roadster reach china great wall tesla op...
# 2  tesla roadster get version 25 upgrade tesla re...
#
#                                           embeddings
# 0  [0.0, 0.0, 0.05688175319791961, 0.057300791092...
# 1  [0.0, 0.0, 0.06517399589612359, 0.087538828382...
# 2  [0.0, 0.0, 0.0, 0.0, 0.06776105760509844, 0.0,...

# %%
df.to_csv('Word_Embedding.csv', index=False)
